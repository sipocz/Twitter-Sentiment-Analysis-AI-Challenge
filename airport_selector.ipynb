# %% [markdown]
# <a href="https://colab.research.google.com/github/sipocz/Twitter-Sentiment-Analysis-AI-Challenge/blob/main/airport_selector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
airports_path="https://github.com/sipocz/Twitter-Sentiment-Analysis-AI-Challenge/raw/2039827e9c4ef351ad3ca196027dbc708c892554/airports.csv"
# !rm airports*

# !wget $airports_path

df_airport=pd.read_csv("airports.csv")
# Out:
# rm: cannot remove 'airports*': No such file or directory
# --2021-10-10 15:10:14--  https://github.com/sipocz/Twitter-Sentiment-Analysis-AI-Challenge/raw/2039827e9c4ef351ad3ca196027dbc708c892554/airports.csv
# Resolving github.com (github.com)... 52.192.72.89
# Connecting to github.com (github.com)|52.192.72.89|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/sipocz/Twitter-Sentiment-Analysis-AI-Challenge/2039827e9c4ef351ad3ca196027dbc708c892554/airports.csv [following]
# --2021-10-10 15:10:15--  https://raw.githubusercontent.com/sipocz/Twitter-Sentiment-Analysis-AI-Challenge/2039827e9c4ef351ad3ca196027dbc708c892554/airports.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
df_airport.tail(50)
# Out:
#            id  ...                 keywords
# 67970   31731  ...                    Kucha
# 67971   31771  ...                      NaN
# 67972   35310  ...                      NaN
# 67973  313426  ...                      NaN
# 67974  316548  ...                      NaN
# 67975  333070  ...                      NaN
# 67976  326731  ...                      NaN
# 67977   27234  ...            Kashi Airport
# 67978   32406  ...                      NaN
# 67979   28144  ...                      NaN
# 67980   27235  ...  Khotan, Heitan Air Base
# 67981  314799  ...                      NaN
# 67982   27236  ...                      NaN
# 67983   32725  ...                      NaN
# 67984  342843  ...                      NaN
# 67985   30646  ...                      NaN
# 67986   27237  ...                      NaN
# 67987  300858  ...                      NaN
# 67988   30827  ...                      NaN
# 67989  327349  ...                      NaN
# ...

# %%
DFW-CLT

# %%
df_airport[df_airport.iata_code=="CLT"].head()
# Out:
#          id ident  ...                                     wikipedia_link keywords
# 32387  3457  KCLT  ...  https://en.wikipedia.org/wiki/Charlotte/Dougla...      NaN
#
# [1 rows x 18 columns]
